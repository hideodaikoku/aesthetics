# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
df = pd.read_csv('../output/IRR.csv', sep=',',header=None)

# %%
df
# Out:
#          0         1         2         3         4        5         6  \
# 0  0.00000  0.305770  0.080392  0.032697  0.686230  0.00010  0.251970
# 1  0.03844  0.000000  0.009399  0.485050  0.426060  0.00010  0.226680
# 2  0.11520  0.181400  0.000000  0.717930  0.857810  0.00010  0.006699
# 3  0.14440  0.004377 -0.045550  0.000000  0.190280  0.00010  0.120690
# 4 -0.03460  0.012570 -0.078900  0.064880  0.000000  0.00010  0.703530
# 5  0.57530  0.347300  0.354700  0.588700  0.326000  0.00000  0.019098
# 6  0.06485  0.059210  0.222300  0.092320 -0.037340  0.17040  0.000000
# 7 -0.13450 -0.054870 -0.073220  0.015530  0.086410 -0.07954  0.105600
# 8  0.08523 -0.052440  0.144400  0.001549 -0.059020  0.10540 -0.106200
# 9  0.05522 -0.018000  0.191800  0.016040 -0.003022  0.13860  0.328200
#
#          7         8         9
# 0  0.95130  0.233880  0.285870
# 1  0.76562  0.709130  0.577540
# 2  0.83392  0.084592  0.025397
# 3  0.42206  0.485950  0.418360
# 4  0.11549  0.802520  0.521150
# 5  0.84402  0.145190  0.073993
# 6  0.10629  0.857410  0.000300
# 7  0.00000  0.565840  0.000100
# 8 -0.02161  0.000000  0.000100
# 9  0.45480  0.732800  0.000000

# %%
labels = pd.read_csv('../output/labels.csv', sep=',')

# %%
labels=labels.values

# %%
labels = ['Annotator 1','Annotator 2', 'Annotator 3','Annotator 4','Annotator 5','Annotator Avg.','Algorithm 1 ','Algorithm 2 ','Algorithm 3','Algorithm Average']

# %%
df
# Out:
#          0         1         2         3         4        5         6  \
# 0  0.00000  0.305770  0.080392  0.032697  0.686230  0.00010  0.251970
# 1  0.03844  0.000000  0.009399  0.485050  0.426060  0.00010  0.226680
# 2  0.11520  0.181400  0.000000  0.717930  0.857810  0.00010  0.006699
# 3  0.14440  0.004377 -0.045550  0.000000  0.190280  0.00010  0.120690
# 4 -0.03460  0.012570 -0.078900  0.064880  0.000000  0.00010  0.703530
# 5  0.57530  0.347300  0.354700  0.588700  0.326000  0.00000  0.019098
# 6  0.06485  0.059210  0.222300  0.092320 -0.037340  0.17040  0.000000
# 7 -0.13450 -0.054870 -0.073220  0.015530  0.086410 -0.07954  0.105600
# 8  0.08523 -0.052440  0.144400  0.001549 -0.059020  0.10540 -0.106200
# 9  0.05522 -0.018000  0.191800  0.016040 -0.003022  0.13860  0.328200
#
#          7         8         9
# 0  0.95130  0.233880  0.285870
# 1  0.76562  0.709130  0.577540
# 2  0.83392  0.084592  0.025397
# 3  0.42206  0.485950  0.418360
# 4  0.11549  0.802520  0.521150
# 5  0.84402  0.145190  0.073993
# 6  0.10629  0.857410  0.000300
# 7  0.00000  0.565840  0.000100
# 8 -0.02161  0.000000  0.000100
# 9  0.45480  0.732800  0.000000

# %%
matplotlib.rcParams.update({'font.size': 22})
fig, ax = plt.subplots(figsize=(34.4,15))
colormap = plt.cm.get_cmap('BuPu_r')
ax = sns.heatmap(df, annot=True, linewidths=.5,cmap ="PuBu")
mask = np.zeros_like(df)
mask[np.tril_indices_from(mask)] = True
with sns.axes_style("white"):
    asx = sns.heatmap(df, mask=mask,annot=True, linewidths=.5, cmap =colormap)
asx.set_yticklabels(labels, rotation =0)
asx.set_xticklabels(labels, rotation =60)
# Out:
# [Text(0.5, 0, 'Annotator 1'),
#  Text(1.5, 0, 'Annotator 2'),
#  Text(2.5, 0, 'Annotator 3'),
#  Text(3.5, 0, 'Annotator 4'),
#  Text(4.5, 0, 'Annotator 5'),
#  Text(5.5, 0, 'Annotator Avg.'),
#  Text(6.5, 0, 'Algorithm 1 '),
#  Text(7.5, 0, 'Algorithm 2 '),
#  Text(8.5, 0, 'Algorithmn 3'),
#  Text(9.5, 0, 'Algorithm Average')]
